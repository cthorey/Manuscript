# %%
# %matplotlib inline
import os
from nltk import *

# %%
from wordcloud import WordCloud, STOPWORDS
Root = "/Users/thorey/Documents/These/Manuscript/"
chap2 = os.path.join(Root,'Chapter','Chapter2.tex')
chap3 = os.path.join(Root,'Chapter','Chapter3.tex')
chap4 = os.path.join(Root,'Chapter','Chapter4.tex')
chap5 = os.path.join(Root,'Chapter','Chapter5.tex')
chap6 = os.path.join(Root,'Chapter','Chapter6.tex')

def WordCloudT(Chap,NameWC):
    word_final = []
    for chap in Chap:
        text = open(chap,'r')
        tokenizer = RegexpTokenizer(r'\w+')
        FilterWord = ['citep','citet','begin','end','frac','partial']
        FilterWord += ['h_0','Lambda','eta_h','Figure','label','ref','left','right']
        word = [f for f in tokenizer.tokenize(text.read()) if len(f)>2]
        wordf = filter(lambda x:x not in FilterWord,word)
        word_final += wordf
    fo = open(os.path.join(Root,'word_tmp.txt'), "w")
    fo.write("\n".join(list(set(word_final))))
    fo.close()
    
    mask = imread(path.join(Root,'Figure','WordCloud',"Boule.jpg"))
    wc = WordCloud(background_color="white", max_words=2000, mask=mask,
                   stopwords=STOPWORDS.add("chocolat"))
    # generate word cloud
    Input = open(os.path.join(Root,'word_tmp.txt')).read()
    wc.generate(Input)
    # store to file
    wc.to_file(os.path.join(Root,NameWC))
    return wc

# %%
Im = WordCloudT([chap3,chap4],'Cooling.png')
figure,ax = plt.subplots(20,20)
ax.imshow(Im)
ax.axis("off")

# %%
from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt

from wordcloud import WordCloud, STOPWORDS

# Read the whole text.
fo = open(os.path.join(image,"Texte.txt"), "w")
fo.write("\n".join(wordf))
fo.close()
text =  open(os.path.join(image,"Texte.txt")).read()


# read the mask image
# taken from
# http://www.stencilry.org/stencils/movies/alice%20in%20wonderland/255fk.jpg
alice_mask = imread(path.join(image, "Boule.jpg"))

wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
               stopwords=STOPWORDS.add("chocolat"))
# generate word cloud
wc.generate(text)

# store to file
wc.to_file(path.join(image, "alice.png"))

# show
plt.imshow(wc)
plt.axis("off")
plt.figure()
plt.imshow(alice_mask, cmap=plt.cm.gray)
plt.axis("off")
plt.show()

# %%
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize, sent_tokenize

Tofilter= ['\\frac','.',',','\\partial','{','}','\\end','\\label','\\subsection']
Tofilter+= ['\\Lambda','>','<','1','\\epsilon','$','\\\\']
with open(bib, "r") as text:
    tokens = [word for sent in sent_tokenize(text.read()) for word in word_tokenize(sent)]
    word = filter(lambda word: word not in Tofilter, tokens)

# %%
FreqDist?
